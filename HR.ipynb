# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:\DATA\HR_comma_sep.csv')

# %%
data.shape
# Out:
# (14999, 10)

# %%
data.duplicated().sum()
# Out:
# 3008

# %%
data[data.duplicated()==1]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 396                  0.46             0.57               2
# 866                  0.41             0.46               2
# 1317                 0.37             0.51               2
# 1368                 0.41             0.52               2
# 1461                 0.42             0.53               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 396                     139                   3              0     1
# 866                     128                   3              0     1
# ...

# %%
data[(data['satisfaction_level']==0.46) & (data['average_montly_hours']==139)   & (data['time_spend_company']==3) ]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 23                   0.46             0.57               2
# 396                  0.46             0.57               2
# 12023                0.46             0.57               2
# 12396                0.46             0.57               2
# 14234                0.46             0.57               2
# 14607                0.46             0.57               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 23                      139                   3              0     1
# 396                     139                   3              0     1
# 12023                   139                   3              0     1
# 12396                   139                   3              0     1
# 14234                   139                   3              0     1
# 14607                   139                   3              0     1
#
#        promotion_last_5years Department salary
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data[(data['satisfaction_level']==0.46) & (data['average_montly_hours']==139)   & (data['time_spend_company']==3) ]
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 23                0.46             0.57               2                   139
#
#     time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 23                   3              0     1                      0      sales
#
#    salary
# 23    low
